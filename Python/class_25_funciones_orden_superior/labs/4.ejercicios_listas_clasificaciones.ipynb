# %% [markdown]
# # Listas y clasificaciones (o máscaras booleanas)
#
# -----------------------

# %% [markdown]
# ### Contado condicional
#
# Tu objetivo es crear la función `count_if` que recibe una lista y una clasificación. Devuelve un `int`. La función debe de recorrer la lista recibida y cuenta todos aquellos elementos cuyo booleano correspondiente (en la clasificación) sea `True`.
#
# Si alguna de las dos listas es la vacía, devuelve 0. Si la longitud de las dos listas no es igual, debe de lanzar un `ValueError`.
#
# Algunos ejemplos:
#
# * `count_if([], [True, False, True])` -> `0`
# * `count_if(["Hola", "Mundo", "q", "kdx", "APL"], [False, False, True, True, True])` -> `3`
#
# Asegúrate de crear los requisitos para la función, su firma con información de tipado, la cadena de documentación y su correcta implementación.

# %% [markdown]
# ### Sumado condicional
#
# Crea la función equivalente que en vez de simplemente contar, lo que hace es **sumar** los valores. Debe de recibir una lista de `int|float`y una clasificación de la misma longitud.

# %% [markdown]
# ### Aplicación condicional
#
# La función `apply_if` *generaliza lo anterior*. Esta función recibe:
#
# * una lista de elementos a procesar
# * una clasificación para saber a qué elemento procesar
# * una función que recibe un parámetro (el elemento a procesar), le hace algo y devuelve el resultado.
#
# 1. Si cualquiera de la listas es vacía, debe de devolver `None`. ¿Por qué no `0`? Piensa.
# 2. Si la longitud de las dos listas es distinta, debe de lanzar `ValueError`
#
# Asegúrate de crear los requisitos para la función, su firma con información de tipado, la cadena de documentación y su correcta implementación.
#
# Cuando la tengas, piensa en qué funciones deberías de pasarle a `apply_if` para que sea equivalente a `count_if` y `sum_if` respectivamente. Es decir, ¿qué tendrías que rellenar en estos casos para que estos asserts sean verdaderos?
#
# ```Python
# elts = [1,2,3,4]
# mask = [True, True, False, True]
# assert apply_if(elts, mask, lambda x: ???) == count_if(elts, mask)
# assert apply_if(elts, mask, lambda a: ???) == sum_if(elts, mask)
# ```

# %% [markdown]
# ### Funciones `countif` y `sumif`
#
# Averigua si Excel o Google Sheets tienen funciones llamadas `countif` y `sumif`. ¿Se parecen en algo a nuestras `count_if` y `sum_if`?
#
# ¿Dirías que las hojas de cálculo son lenguajes de programación?
